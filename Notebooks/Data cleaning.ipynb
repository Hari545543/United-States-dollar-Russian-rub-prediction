# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Collab/USD | RUB prediction/USD_RUB.csv")
df.head()
# Out:
#           Date    Price     Open     High      Low Change %
# 0  Apr 14 2022  80.9957  79.8675  82.3836  79.8563    1.41%
# 1  Apr 13 2022  79.8675  79.6800  80.2965  79.4078    0.24%
# 2  Apr 12 2022  79.6800  79.0650  80.2549  78.6952    0.78%
# 3  Apr 11 2022  79.0650  76.0800  81.2950  76.0800    3.92%
# 4  Apr 08 2022  76.0800  75.7500  76.2590  71.3993    0.44%

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.shape
# Out:
# (5320, 6)

# %% [markdown]
# Russian invasion on Ukraine started on Feb 24 2022

# %%
i=0
for var in df.index:
  if(df["Date"][var] == "Feb 24 2022"):
    break

# %% [markdown]
# **The "df1" will be used to train the model**

# %%
df1 = df.iloc[var+1:]
df1.head()
# Out:
#            Date    Price     Open     High      Low Change %
# 36  Feb 23 2022  81.1480  78.8300  81.8605  78.5456    3.24%
# 37  Feb 22 2022  78.5987  80.1485  80.9408  78.4972   -1.77%
# 38  Feb 21 2022  80.0170  77.9465  80.3438  76.1358    3.47%
# 39  Feb 18 2022  77.3320  76.3088  77.4832  75.6440    1.34%
# 40  Feb 17 2022  76.3088  75.2537  76.6241  75.2525    1.40%

# %% [markdown]
# **The "df0" will be used to test the model**

# %%
df0 = df.iloc[:var+1]
df0.head()
# Out:
#           Date    Price     Open     High      Low Change %
# 0  Apr 14 2022  80.9957  79.8675  82.3836  79.8563    1.41%
# 1  Apr 13 2022  79.8675  79.6800  80.2965  79.4078    0.24%
# 2  Apr 12 2022  79.6800  79.0650  80.2549  78.6952    0.78%
# 3  Apr 11 2022  79.0650  76.0800  81.2950  76.0800    3.92%
# 4  Apr 08 2022  76.0800  75.7500  76.2590  71.3993    0.44%

# %%
df0 = df0.drop(['Date'], axis = 1)
df1 = df1.drop(['Date'], axis = 1)

# %% [markdown]
# **Checking for NULL values**

# %%
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64

# %% [markdown]
# # Plotting histograms and bar chart

# %%
sns.histplot(x='Price',data = df)

# %%
sns.histplot(x='Open',data = df)

# %%
sns.histplot(x='High',data = df)

# %%
sns.histplot(x='Low',data = df)

# %% [markdown]
# # Splitting

# %%
X_train = df1.drop(['Change %', 'Price'], axis = 1)
X_test = df0.drop(['Change %', 'Price'], axis = 1)

# %%
Y_train = df1['Price']
Y_test = df0['Price']
Y.head()
# Out:
# 0    80.9957
# 1    79.8675
# 2    79.6800
# 3    79.0650
# 4    76.0800
# Name: Price, dtype: float64

# %%
print(X_train.shape, X_test.shape)
# Out:
# (5284, 3) (36, 3)

# %%
print(Y_train.shape, Y_test.shape)
# Out:
# (5284,) (36,)

# %%
X_train.to_csv("/content/drive/MyDrive/Collab/USD | RUB prediction/X_train.csv", index=False)

# %%
Y_train.to_csv("/content/drive/MyDrive/Collab/USD | RUB prediction/Y_train.csv", index=False)

# %%
X_test.to_csv("/content/drive/MyDrive/Collab/USD | RUB prediction/X_test.csv", index=False)

# %%
Y_test.to_csv("/content/drive/MyDrive/Collab/USD | RUB prediction/Y_test.csv", index=False)
